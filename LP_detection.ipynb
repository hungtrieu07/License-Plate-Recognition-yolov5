# %% [markdown]
# <a href="https://colab.research.google.com/github/hungtrieu07/License-Plate-Recognition-yolov5/blob/master/LP_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Aug 12 09:30:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
#      |████████████████████████████████| 157 kB 60.5 MB/s
#      |████████████████████████████████| 181 kB 71.8 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#      |████████████████████████████████| 157 kB 70.1 MB/s
#      |████████████████████████████████| 157 kB 68.8 MB/s
#      |████████████████████████████████| 157 kB 71.6 MB/s
#      |████████████████████████████████| 156 kB 74.9 MB/s
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !unzip '/content/drive/MyDrive/LP_data/LP_detection.zip' -d '/content/datasets'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3538.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3539.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen354.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3540.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3543.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3544.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3545.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3546.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3547.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3548.txt
#   inflating: /content/datasets/LP_detection/labels/train/CarLongPlateGen3549.txt
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12621, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 12621 (delta 0), reused 1 (delta 0), pack-reused 12618
# Receiving objects: 100% (12621/12621), 12.52 MiB | 32.20 MiB/s, done.
# Resolving deltas: 100% (8653/8653), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.1 MB/s

# %%
# !python train.py --img 320 --batch 32 --epochs 30 --data /content/yolov5/data/LP_detection.yaml --weights yolov5m.pt --cache
# Out:
# wandb: Currently logged in as: hungtrieu07. Use `wandb login --relogin` to force relogin
# train: weights=yolov5m.pt, cfg=, data=/content/yolov5/data/LP_detection.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=32, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-386-g2e57b84 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !unrar x '/content/drive/MyDrive/wpod-net/output' '/content/test/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --data /content/yolov5/data/LP_detection.yaml --img 416 --conf 0.4 --source /content/test/output
# Out:
# Streaming output truncated to the last 5000 lines.
# image 2175/7172 /content/test/output/5_1835_3.jpg: 416x352 1 license_plate, Done. (0.011s)
# image 2176/7172 /content/test/output/5_1836_3.jpg: 384x416 1 license_plate, Done. (0.011s)
# image 2177/7172 /content/test/output/5_1837_3.jpg: 384x416 1 license_plate, Done. (0.011s)
# image 2178/7172 /content/test/output/5_1838_2.jpg: 416x352 1 license_plate, Done. (0.011s)
# image 2179/7172 /content/test/output/5_1838_3.jpg: 384x416 1 license_plate, Done. (0.011s)
# image 2180/7172 /content/test/output/5_1839_2.jpg: 416x352 1 license_plate, Done. (0.011s)
# image 2181/7172 /content/test/output/5_1839_3.jpg: 384x416 1 license_plate, Done. (0.011s)
# image 2182/7172 /content/test/output/5_1840_3.jpg: 384x416 1 license_plate, Done. (0.010s)
# image 2183/7172 /content/test/output/5_1841_2.jpg: 416x352 1 license_plate, Done. (0.015s)
# image 2184/7172 /content/test/output/5_1841_3.jpg: 384x416 1 license_plate, Done. (0.011s)
# ...
